# %% [markdown]
# ### Loops - Repetition

# %% [markdown]
# #### Aufgabe 1

# %% [markdown]
# Schreiben Sie ein Programm, das alle Zahlen von 1 bis 20 ausgibt und dabei überprüft, ob die Zahl gerade oder ungerade ist.
#
# Gib für jede Zahl aus:
# "<Zahl> ist gerade" oder
# "<Zahl> ist ungerade".

# %% [markdown]
# <details><summary>Lösung</summary>
#
# ```python
# for i in range(1, 21):
#     if i % 2 == 0:
#         print(f'{i} ist gerade')
#     else:
#         print(f'{i} ist ungerade')
# ```
#
# </details>

# %% [markdown]
# #### Aufgabe 2

# %% [markdown]
# Schreiben Sie ein Programm, das den/die Benutzer:in nach einem Passwort fragt.
#
# Solange das eingegebene Passwort nicht korrekt ist, wird der/die Benutzer:in erneut aufgefordert, ein Passwort einzugeben.
# Sobald das Passwort richtig ist, soll das Programm die Nachricht „Zugang gewährt!“ ausgeben.

# %% [markdown]
# <details><summary>Lösung</summary>
#
# ```python
# richtig = 'python'
# while True:
#     pw = input('Passwort: ')
#     if pw == richtig:
#         print('Zugang gewährt!')
#         break
#     else:
#         print('Falsch, versuch es erneut.')
# ```
#
# </details>

# %% [markdown]
# #### Zusatzaufgabe
# while-Schleife: Zähle von 30 rückwärts und gib nur gerade Zahlen aus.

# %% [markdown]
# <details><summary>Lösung</summary>
#
# ```python
# zahl = 30
# while zahl >= 0:
#     if zahl % 2 == 0:
#         print(zahl)
#     zahl -= 1
# ```
#
# </details>

# %% [markdown]
# #### Zusatzaufgabe 2
# for-Schleife: Gib die Vielfachen von 3 bis 60 aus.

# %% [markdown]
# <details><summary>Lösung</summary>
#
# ```python
# for i in range(0,61,3):
#     print(i)
# ```
#
# </details>
